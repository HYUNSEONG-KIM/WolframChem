# %%
import pubchempy as pcp

# %%
listd = pcp.get_cids('2-nonenal', 'name', 'substance', list_return='flat')

# %%
listd
# Out:
# [17166, 5283335, 5354833]

# %%
pcp.get_compounds(listd,"cid",as_dataframe=True)
# Out:
#          atom_stereo_count                                              atoms  \
# cid
# 17166                    0  [{'aid': 1, 'number': 8, 'element': 'O', 'y': ...
# 5283335                  0  [{'aid': 1, 'number': 8, 'element': 'O', 'y': ...
# 5354833                  0  [{'aid': 1, 'number': 8, 'element': 'O', 'y': ...
#
#          bond_stereo_count                                              bonds  \
# cid
# 17166                    1  [{'aid1': 1, 'aid2': 10, 'order': 2}, {'aid1':...
# 5283335                  1  [{'aid1': 1, 'aid2': 10, 'order': 2}, {'aid1':...
# 5354833                  1  [{'aid1': 1, 'aid2': 10, 'order': 2}, {'aid1':...
#
#                                         cactvs_fingerprint canonical_smiles  \
# cid
# 17166    1110000001110000001000000000000000000000000000...     CCCCCCC=CC=O
# 5283335  1110000001110000001000000000000000000000000000...     CCCCCCC=CC=O
# 5354833  1110000001110000001000000000000000000000000000...     CCCCCCC=CC=O
#
# ...
